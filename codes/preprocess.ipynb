# %%
import pandas as pd

# %%
df = pd.read_csv('../data/A_FullClean_CountData.csv')
df.shape
# Out:
# (23148, 19)

# %%
df_transposed = df.T
df_transposed.head()
# Out:
#                      0                   1                   2      \
# ID      ENSRNOG00000046319  ENSRNOG00000050370  ENSRNOG00000040300
# TCPS.1                   1                   0                  10
# TCPS.2                   0                   0                  11
# TCPS.3                   0                   0                  10
# OM.1                     0                   0                  10
#
#                      3                   4                   5      \
# ID      ENSRNOG00000058808  ENSRNOG00000061316  ENSRNOG00000040316
# TCPS.1                   0                 834                   5
# TCPS.2                   0                 963                   0
# TCPS.3                   0                 894                   1
# OM.1                     0                 619                   2
#
#                      6                   7                   8      \
# ID      ENSRNOG00000023659  ENSRNOG00000029897  ENSRNOG00000042852
# ...

# %%
implants = ['TCPS', 'OM', 'BMP2', 'PT', 'mSLA', 'Titan']
for imp in implants:
    df_imp = df_transposed[df_transposed.index.str.contains(imp)]
    df_imp.columns = df_transposed.iloc[0]
    df_imp.to_csv(f'../data/countdata_{imp}.tsv', sep='\t', index=False)
